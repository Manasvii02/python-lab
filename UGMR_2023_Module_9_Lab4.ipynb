# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasvii02/python-lab/blob/main/UGMR_2023_Module_9_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 9: Convolutional Neural Networks
# ## **Lab 4**
# ### Module coordinator: Kushagra Agarwal

# %% [markdown]
# <img src="https://miro.medium.com/max/1200/1*QoqNAg2t6lF8Q6WWA6AbOg.png" width=650px/>

# %% [markdown]
# ## Using learnt representations
# In practice, very few people train an entire Convolutional Network from scratch (with random initialization), because it is relatively rare to have a dataset of sufficient size. Instead, it is common to pretrain a ConvNet on a very large dataset (e.g. ImageNet, which contains 1.2 million images with 1000 categories), and then use the ConvNet either as an initialization or a fixed feature extractor for the task of interest.
#
#
# We'll train a model to classify ants and bees. We have about 120 training images each for ants and bees. There are 75 validation images for each class. Usually, this is a very small dataset to generalize upon, if trained from scratch. Since we are using transfer learning, we should be able to generalize reasonably well.
#
# This dataset is a very small subset of imagenet.

# %%
# Import packages
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, SubsetRandomSampler
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import matplotlib.pyplot as plt
import numpy as np
import time
import os

# %%
# Device configuration (whether to run on GPU or CPU)
device = 'cpu' #torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Download and extract dataset
# !wget https://download.pytorch.org/tutorial/hymenoptera_data.zip
# !unzip -q hymenoptera_data.zip
# Out:
# --2024-05-19 04:20:31--  https://download.pytorch.org/tutorial/hymenoptera_data.zip
# Resolving download.pytorch.org (download.pytorch.org)... 13.225.4.109, 13.225.4.25, 13.225.4.31, ...
# Connecting to download.pytorch.org (download.pytorch.org)|13.225.4.109|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47286322 (45M) [application/zip]
# Saving to: ‘hymenoptera_data.zip’
#
# hymenoptera_data.zi 100%[===================>]  45.10M  --.-KB/s    in 0.1s
#
# 2024-05-19 04:20:32 (376 MB/s) - ‘hymenoptera_data.zip’ saved [47286322/47286322]

# %%
# Data augmentation and normalization for training
# Just normalization for validation
train_transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
val_transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

data_dir = './hymenoptera_data'
train_dataset = ImageFolder(os.path.join(data_dir, 'train'), train_transform)
val_dataset = ImageFolder(os.path.join(data_dir, 'val'), val_transform)
train_dataloader = DataLoader(train_dataset, batch_size=4,shuffle=True, num_workers=2)
val_dataloader = DataLoader(val_dataset, batch_size=4,shuffle=True, num_workers=2)
class_names = train_dataset.classes

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(train_dataloader))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %%
def train_model(model, train_dataloader, criterion, optimizer, num_epochs=25):

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)
        model.train()
        running_loss = 0.0
        running_corrects = 0

        # Iterate over data.
        for i, (inputs, labels) in enumerate(train_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward
            # track history if only in train
            with torch.set_grad_enabled(True):
              outputs = model(inputs)
              _, preds = torch.max(outputs, 1)
              loss = criterion(outputs, labels)

              # backward + optimize only if in training phase
              loss.backward()
              optimizer.step()

            # statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(train_dataloader.dataset)
        epoch_acc = running_corrects.double() / len(train_dataloader.dataset)

        print(f'Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

        print()

# %%
def visualize_model(model, num_images=10):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(val_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
from torchvision import models

model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

loss_func = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 54.2MB/s]

# %%
num_epochs = 5
train_model(model_ft, train_dataloader, loss_func, optimizer, num_epochs)
# Out:
# Epoch 0/4
# ----------
# Loss: 0.6240 Acc: 0.6844
#
# Epoch 1/4
# ----------
# Loss: 0.5641 Acc: 0.7664
#
# Epoch 2/4
# ----------
# Loss: 0.4440 Acc: 0.8074
#
# Epoch 3/4
# ----------
# Loss: 0.6431 Acc: 0.7459
#
# Epoch 4/4
# ----------
# Loss: 0.6676 Acc: 0.7500

# %%
visualize_model(model_ft)

# %% [markdown]
# ## Example of How Pretrained models are used for Target Tasks

# %% [markdown]
# <img src="https://www.researchgate.net/publication/340225334/figure/fig2/AS:960014822944773@1605896778155/Mechanism-of-transfer-learning-using-pre-trained-models.png" width=950px/>

# %% [markdown]
# ## Questions:
# 1) What is the significance of using data augmentations like resize, crop etc on training data?
#
# 2) What performance do you get if you don't use pretrained resnet model (Hint: Change pretrained=False and train the model)
#
# 3) If the resnet model was pre-trained on dataset significantly different than the ants vs bees data, would you still get good performance by using this pretrained model?

# %% [markdown]
# Ans1)-
# ChatGPT
# Data augmentation techniques such as resizing, cropping, and others have significant benefits when used on training data for machine learning models, especially in the context of image data and Convolutional Neural Networks (CNNs). Here are the key reasons for using these techniques:
#
# 1. Increase Dataset Size
# Data augmentation artificially increases the size of the training dataset by creating modified versions of existing images. This is particularly valuable when the original dataset is small, as it helps to prevent overfitting by providing the model with more varied examples to learn from.
#
# 2. Improve Generalization
# By exposing the model to various transformations of the images, data augmentation helps the model to learn more robust features that generalize better to new, unseen data. This means the model is less likely to rely on specific details of the training images and more likely to perform well on a wider range of inputs.
#
# 3. Reduce Overfitting
# Augmentations introduce variations in the training data, which makes it harder for the model to memorize the training samples. Instead, the model has to learn to recognize patterns that are consistent across these variations, which reduces the risk of overfitting to the training data.
#
# 4. Simulate Real-World Variations
# In real-world scenarios, images might be captured from different angles, under varying lighting conditions, or with different backgrounds. Data augmentations like resizing, cropping, rotating, flipping, and adding noise simulate these real-world variations, making the model more robust to such changes.
#
# 5. Improve Model Performance
# Overall, data augmentation often leads to better model performance. The increased variety in training data helps the model to learn more comprehensive features, which typically results in higher accuracy and better performance on the validation and test sets.
#
# Ans2)-If you train a ResNet model from scratch without using pretrained weights (pretrained=False), the performance can vary significantly depending on several factors:
#
# Factors Influencing Performance
# Dataset Size: Large datasets are typically required to achieve good performance when training deep models from scratch. Small datasets might lead to overfitting and poor generalization.
# Training Time: Training a ResNet model from scratch requires more epochs and computational resources compared to fine-tuning a pretrained model.
# Hyperparameters: Proper tuning of hyperparameters like learning rate, batch size, weight decay, etc., is crucial for achieving good performance.
# Data Augmentation: Effective data augmentation techniques can help improve performance by providing more diverse training samples.
# Expected Performance
# Without pretrained weights, a ResNet model might initially perform poorly compared to a pretrained version. The pretrained model benefits from the knowledge gained from a large and diverse dataset (like ImageNet), allowing it to generalize better on new tasks. Here’s a general outline of what you might expect:
#
# Initial Performance: When starting from scratch, the initial performance (accuracy, loss, etc.) will likely be low.
# Learning Rate and Convergence: Training from scratch might require a carefully chosen learning rate schedule to ensure proper convergence. The training process might be slower, and the model may require more epochs to reach a comparable performance level.
# Final Performance: Given enough data and proper training, a ResNet model trained from scratch can eventually reach high performance. However, it may still underperform compared to a model initialized with pretrained weights, especially if the training dataset is not large or diverse enough.
# Specific Example
#
# Ans3)-Using a pretrained ResNet model on a dataset significantly different from its original training data can still provide substantial benefits, though the performance gains might not be as pronounced as when the pretraining dataset is more similar to the target dataset. Here's a detailed look at the implications and outcomes:
#
# Benefits of Using a Pretrained Model
# Feature Extraction: Pretrained models, like ResNet, have learned a variety of low-level and mid-level features (edges, textures, shapes) that are generally useful for many types of images. These features are often transferable even if the pretraining and target datasets are different.
# Faster Convergence: Pretrained models help in faster convergence compared to training from scratch. The model already has a good starting point in terms of weights and can adapt more quickly to the new data.
# Regularization Effect: Using a pretrained model can act as a form of regularization, preventing the model from overfitting to the new, potentially smaller dataset.
# Challenges and Considerations
# Domain Shift: If the pretraining dataset is very different from the ants vs. bees dataset, the high-level features learned may not be as relevant. For instance, a model pretrained on medical images may not be as effective for classifying insects without additional fine-tuning.
# Fine-Tuning: Fine-tuning the pretrained model on the new dataset becomes crucial. Freezing the lower layers (which learn general features) and retraining the higher layers (which learn more specific features) can help adapt the model to the new task.
# Data Augmentation: Using robust data augmentation techniques can help the model generalize better to the target dataset by providing more varied training examples.
